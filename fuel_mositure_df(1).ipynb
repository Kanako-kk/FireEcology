# %% [markdown]
# ![pic of poster.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# 4 documents needed
#
#
# # 1.   Fuel Moisture Bottle Weight - record weight: fuel mositure percent
# # 2.   Horticultural live fuel moisture (Responses): bottle information
#
# # 1.   HIZ plant info, site info, etc, - plant: plant characteristics
#
# # 1.   HIZ plant info, site info, etc, - site, data collector, semester: Irrigation info
#
#
#
#
# They all can be found on HIZ folder

# %% [markdown]
# Importing data

# %%
from google.colab import files
files_uploaded = files.upload()
# Out:
#      <input type="file" id="files-5601eeec-4c92-444d-81f4-2ace9e367233" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5601eeec-4c92-444d-81f4-2ace9e367233">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Fuel Moisture Bottle Weight - record weight(3).csv to Fuel Moisture Bottle Weight - record weight(3).csv

# %%
import pandas as pd 
df1= pd.read_csv(r'Fuel Moisture Bottle Weight - record weight(3).csv')
df1.dtypes #check datatypes
# Out:
# EMPTY Collector               object
# EMPTY Date (MM/DD/YYYY)       object
# EMPTY Bottle number          float64
# EMPTY (gram)                 float64
# EMPTY Comment                float64
# WET Collector                 object
# WET Date (MM/DD/YYYY)         object
# WET Bottle number            float64
# WET (gram)                   float64
# Oven (C°)                    float64
# WET Comment                   object
# DRY Collector                 object
# DRY Date (MM/DD/YYYY)         object
# DRY Bottle number            float64
# DRY (gram)                   float64
# Oven (°C)                    float64
# DRY Comment                   object
# empty and wet match            int64
# wet and dry match            float64
# empty weigh less than wet    float64
# wet weigh more than dry       object
# in oven 1 day                float64
# fuel moisture percent         object
# Overall comment               object
# dtype: object

# %% [markdown]
# quality control + changing datatypes

# %%
#drop undesired columns 
df1=df1[df1['WET Collector'].notna()]
df1=df1[df1['empty and wet match']==0]
df1=df1[df1['wet and dry match']==0.0]
#changing datatype of "emmpty weigh less than wet" string to numeric 
df1["empty weigh less than wet"] = pd.to_numeric(df1["empty weigh less than wet"], errors='coerce')
df1=df1[df1['empty weigh less than wet']<0]
#to make the merging easy, changing WET date to string datatype 
df1['WET Date (MM/DD/YYYY)'] = pd.to_datetime(df1['WET Date (MM/DD/YYYY)'])
#fuel moisture object to numeric 
df1["fuel moisture percent"] = pd.to_numeric(df1["fuel moisture percent"], errors='coerce')

# %% [markdown]
# Importing data

# %%
from google.colab import files
files_uploaded = files.upload()
# Out:
#      <input type="file" id="files-eb71b557-7c5d-4934-9350-7f4117435659" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb71b557-7c5d-4934-9350-7f4117435659">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Horticultural live fuel moisture (Responses) - Form Responses 1.csv to Horticultural live fuel moisture (Responses) - Form Responses 1.csv

# %%
df2=pd.read_csv(r'Horticultural live fuel moisture (Responses) - Form Responses 1.csv')

# %%
df2.dtypes
# Out:
# Timestamp                                                                                                                  object
# Email Address                                                                                                              object
# Score                                                                                                                     float64
# Field data collector                                                                                                       object
# Location                                                                                                                   object
# Common plant name                                                                                                          object
# What is the NEW GROWTH fuel's bottle matching number on the bottle and cap?                                               float64
# New growth (choose one, unless starting and continuing)                                                                    object
# Flowering (choose one, unless starting & peaking OR peaking & declining)                                                   object
# Fruit                                                                                                                      object
# Phenology Comments                                                                                                         object
# General Comments                                                                                                           object
# Weather Comments                                                                                                           object
# What is the OLD GROWTH fuel's bottle matching number on the bottle and cap?                                               float64
# Location.1                                                                                                                 object
# What is the DISEASED & DEAD leaf, etc.  fuel's (still attached to plant) bottle matching number on the bottle and cap?     object
# What is the FLOWER / FRUIT fuel's (still attached to plant) bottle matching number on the bottle and cap?                  object
# Temperature (°F)                                                                                                          float64
# Relative humidity                                                                                                         float64
# dtype: object

# %% [markdown]
# quality control and changing datatypes

# %%
#drop NA values, changing column name
df2=df2[df2['Common plant name']!='NEED TO MAKE DROP-DOWN or Multiple choice?']
df2=df2[df2['Common plant name']!='Option 1']
df2.rename(columns={"What is the NEW GROWTH fuel's bottle matching number on the bottle and cap?": 'New Growth', "What is the OLD GROWTH fuel's bottle matching number on the bottle and cap?": 'Old Growth', "What is the DISEASED & DEAD leaf, etc.  fuel's (still attached to plant) bottle matching number on the bottle and cap?":"Diseased Dead","What is the FLOWER / FRUIT fuel's (still attached to plant) bottle matching number on the bottle and cap?":"Flower Fruit"}, inplace=True)
#changing datatypes object to numeric  
df2["New Growth"] = pd.to_numeric(df2["New Growth"], errors='coerce')
df2["Diseased Dead"] = pd.to_numeric(df2["Diseased Dead"], errors='coerce')
df2["Flower Fruit"] = pd.to_numeric(df2["Flower Fruit"], errors='coerce')
#fixing time stamp format to match the WET date format and match datatype with WET date 
df2["Timestamp"] = pd.to_datetime(df2["Timestamp"]).dt.strftime('%m/%d/%Y')
df2['Timestamp'] = pd.to_datetime(df2['Timestamp'])

# %% [markdown]
# # Merging two table

# %% [markdown]
# primary key for join is date collected and bottle number

# %%
new_table=pd.merge(df1, df2, how='inner', left_on=['WET Date (MM/DD/YYYY)', 'WET Bottle number'], right_on=['Timestamp', 'New Growth'])
new_table=new_table[new_table['New Growth'].notna()]
new_table
# Out:
#    EMPTY Collector EMPTY Date (MM/DD/YYYY)  EMPTY Bottle number  EMPTY (gram)  \
# 0    Jordan Reding              10/14/2021                 32.0         101.5
# 1    Atharv Keskar              10/26/2021                  2.0         102.7
# 2    Atharv Keskar              10/26/2021                  4.0         101.1
# 3    Atharv Keskar              10/26/2021                  5.0         101.8
# 4    Atharv Keskar              10/26/2021                  7.0         102.5
# 5    Atharv Keskar              10/26/2021                 10.0         101.4
# 6    Atharv Keskar              10/26/2021                 26.0         102.2
# 7    Atharv Keskar              10/26/2021                 28.0         102.1
# 8    Atharv Keskar              10/26/2021                 27.0         101.1
# 9    Atharv Keskar              10/26/2021                 42.0         102.2
# 10   Atharv Keskar              10/26/2021                 35.0         102.3
# 11    Skyla Dennis               11/3/2021                 46.0         102.1
# 12     Kanako Kato                 11/4/21                  1.0         102.3
# 13   Jordan Reding                 11/5/21                 31.0         102.2
# 14   Jordan Reding                 11/5/21                 33.0         101.3
# 15   Jordan Reding                 11/5/21                 34.0         101.4
# 16    Skyla Dennis                11/10/21                 25.0         101.5
# 17    Skyla Dennis                11/10/21                 30.0         101.8
# 18   Atharv Keskar                11/16/21                 28.0         101.9
# 19   Atharv Keskar                11/16/21                 31.0         102.0
# 20   Atharv Keskar                11/16/21                 34.0         101.0
# 21    Skyla Dennis                11/17/21                 37.0         102.2
# 22   Atharv Keskar                11/23/21                 26.0         101.8
# 23   Atharv Keskar                11/23/21                 28.0         101.9
# 24   Atharv Keskar                11/23/21                 32.0         101.5
#
#     EMPTY Comment  WET Collector WET Date (MM/DD/YYYY)  WET Bottle number  \
# 0             NaN    Kanako Kato            2021-10-21               32.0
# 1             NaN  Jordan Reding            2021-10-27                2.0
# 2             NaN  Jordan Reding            2021-10-27                4.0
# 3             NaN  Jordan Reding            2021-10-27                5.0
# 4             NaN  Jordan Reding            2021-10-27                7.0
# 5             NaN   Skyla Dennis            2021-10-27               10.0
# 6             NaN   Skyla Dennis            2021-10-27               26.0
# 7             NaN   Skyla Dennis            2021-10-27               28.0
# 8             NaN   Skyla Dennis            2021-10-27               27.0
# 9             NaN   Skyla Dennis            2021-10-27               42.0
# 10            NaN   Skyla Dennis            2021-10-27               35.0
# 11            NaN   Skyla Dennis            2021-11-03               46.0
# 12            NaN    Kanako Kato            2021-11-04                1.0
# 13            NaN  Jordan Reding            2021-11-05               31.0
# 14            NaN  Jordan Reding            2021-11-05               33.0
# 15            NaN  Jordan Reding            2021-11-05               34.0
# 16            NaN   Skyla Dennis            2021-11-10               25.0
# 17            NaN   Skyla Dennis            2021-11-10               30.0
# 18            NaN  Jordan Reding            2021-11-17               28.0
# 19            NaN  Jordan Reding            2021-11-17               31.0
# 20            NaN  Jordan Reding            2021-11-17               34.0
# 21            NaN   Skyla Dennis            2021-11-17               37.0
# 22            NaN  Jordan Reding            2021-11-24               26.0
# 23            NaN  Jordan Reding            2021-11-24               28.0
# 24            NaN  Jordan Reding            2021-11-24               32.0
#
#     WET (gram)  Oven (C°)  ...  \
# 0        112.1        NaN  ...
# 1        181.1       55.0  ...
# 2        169.5       55.0  ...
# 3        246.8       55.0  ...
# 4        182.1       55.0  ...
# 5        129.3       37.0  ...
# 6        129.6       37.0  ...
# 7        170.2       37.0  ...
# 8        133.0       37.0  ...
# 9        147.3       37.0  ...
# 10       140.2       37.0  ...
# 11       161.6       53.0  ...
# 12       112.1       85.0  ...
# 13       193.6       55.0  ...
# 14       173.5       55.0  ...
# 15       244.9       55.0  ...
# 16       159.3        NaN  ...
# 17       171.1        NaN  ...
# 18       171.2       69.0  ...
# 19       284.1       69.0  ...
# 20       203.2       69.0  ...
# 21       139.7       69.0  ...
# 22       211.1       75.0  ...
# 23       195.3       75.0  ...
# 24       276.0       75.0  ...
#
#                                                Fruit   \
# 0   RIPE: Seeds, berries, or nuts appear to be mos...
# 1      FALLEN: Most seeds, berries, or nuts are gone.
# 2   RIPE: Seeds, berries, or nuts appear to be mos...
# 3   PRESENTING: Seeds, berries, or nuts are in vie...
# 4   NONE: Fruit is gone or is rare and isolated to...
# 5   NONE: Fruit is gone or is rare and isolated to...
# 6   NONE: Fruit is gone or is rare and isolated to...
# 7   NONE: Fruit is gone or is rare and isolated to...
# 8   RIPE: Seeds, berries, or nuts appear to be mos...
# 9   NONE: Fruit is gone or is rare and isolated to...
# 10  NONE: Fruit is gone or is rare and isolated to...
# 11  NONE: Fruit is gone or is rare and isolated to...
# 12  RIPE: Seeds, berries, or nuts appear to be mos...
# 13  RIPE: Seeds, berries, or nuts appear to be mos...
# 14  RIPE: Seeds, berries, or nuts appear to be mos...
# 15  RIPE: Seeds, berries, or nuts appear to be mos...
# 16  NONE: Fruit is gone or is rare and isolated to...
# 17  NONE: Fruit is gone or is rare and isolated to...
# 18  PRESENTING: Seeds, berries, or nuts are in vie...
# 19     FALLEN: Most seeds, berries, or nuts are gone.
# 20  NONE: Fruit is gone or is rare and isolated to...
# 21  NONE: Fruit is gone or is rare and isolated to...
# 22     FALLEN: Most seeds, berries, or nuts are gone.
# 23  RIPE: Seeds, berries, or nuts appear to be mos...
# 24     FALLEN: Most seeds, berries, or nuts are gone.
#
#                              Phenology Comments  \
# 0                                           NaN
# 1   Seems to be on the latter of seasonal fruit
# 2                  Many needs seeds and few old
# 3                        Nearly developed seeds
# 4                                      No fruit
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                               ask about seeds
# 9              maybe flowers are starting ask!
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
#
#                                      General Comments  Weather Comments  \
# 0                                                 NaN               NaN
# 1          Some new and old growth with matured seeds             Sunny
# 2   There is a lot of new growth and some old grow...             Sunny
# 3                                   More new than old             Sunny
# 4                           Normal new and old growth             Sunny
# 5                                                 NaN  shady 72 degrees
# 6                                                 NaN       72 degrees
# 7                                                 NaN        72 degrees
# 8                                                 NaN        72 degrees
# 9                                                 NaN        72 degrees
# 10                                                NaN        72 degrees
# 11                                                NaN        66 degrees
# 12                                                NaN               NaN
# 13                                                NaN             Sunny
# 14                                                NaN             Sunny
# 15                                                NaN             Sunny
# 16                                                NaN        66 degrees
# 17                                                NaN        68 degrees
# 18                                                NaN             Sunny
# 19                                                NaN             Sunny
# 20                                                NaN            Sunny
# 21                                                NaN        66 degrees
# 22                                                NaN             Sunny
# 23                                                NaN             Sunny
# 24                                                NaN             Sunny
#
#     Old Growth                                         Location.1  \
# 0         31.0                                  Aquatics entrance
# 1          2.0  San Salvador between 6th and 7th along South P...
# 2          4.0                                 National Bank Gate
# 3          5.0                                 National Bank Gate
# 4          7.0                                    Health Building
# 5         10.0                                       Art Building
# 6         26.0                                   Campus Village 2
# 7         28.0                                   Campus Village 2
# 8         27.0                                       Art Building
# 9         42.0                                   Campus Village 2
# 10        35.0                                   Campus Village 2
# 11        37.0                                   Campus Village 2
# 12         3.0                                  Aquatics entrance
# 13        31.0  San Salvador between 6th and 7th along South P...
# 14        33.0                                 National Bank Gate
# 15        34.0                                 National Bank Gate
# 16        32.0                                   Campus Village 2
# 17        12.0                                   Campus Village 2
# 18        28.0                                 National Bank Gate
# 19        31.0                                 National Bank Gate
# 20        34.0                                    Health Building
# 21        35.0                                   Campus Village 2
# 22        26.0  San Salvador between 6th and 7th along South P...
# 23        28.0                                 National Bank Gate
# 24        32.0                                 National Bank Gate
#
#    Diseased Dead  Flower Fruit  Temperature (°F)  Relative humidity
# 0            NaN           NaN               NaN                NaN
# 1            NaN           2.0               NaN                NaN
# 2            NaN           4.0               NaN                NaN
# 3            NaN           5.0               NaN                NaN
# 4            NaN           NaN               NaN                NaN
# 5            NaN           NaN               NaN                NaN
# 6            NaN           NaN               NaN                NaN
# 7            NaN           NaN               NaN                NaN
# 8            NaN           NaN               NaN                NaN
# 9            NaN           NaN               NaN                NaN
# 10           NaN           NaN               NaN                NaN
# 11           NaN           NaN               NaN                NaN
# 12           NaN           NaN               NaN                NaN
# 13           NaN          31.0               NaN                NaN
# 14           NaN          33.0               NaN                NaN
# 15           NaN          34.0               NaN                NaN
# 16           NaN           NaN               NaN                NaN
# 17           NaN           NaN               NaN                NaN
# 18           NaN          28.0               NaN                NaN
# 19           NaN          31.0               NaN                NaN
# 20           NaN           NaN               NaN                NaN
# 21           NaN           NaN               NaN                NaN
# 22           NaN          26.0               NaN                NaN
# 23           NaN          28.0               NaN                NaN
# 24           NaN           NaN               NaN                NaN
#
# [25 rows x 43 columns]

# %%
old_table=df1.merge(df2, how='inner', left_on=['WET Date (MM/DD/YYYY)','WET Bottle number'], right_on=['Timestamp','Old Growth'])
old_table=old_table[old_table['Old Growth'].notna()]
old_table
# Out:
#    EMPTY Collector EMPTY Date (MM/DD/YYYY)  EMPTY Bottle number  EMPTY (gram)  \
# 0    Jordan Reding              10/14/2021                 31.0         102.0
# 1    Jordan Reding              10/14/2021                 33.0         101.4
# 2    Jordan Reding              10/14/2021                 47.0         101.2
# 3    Atharv Keskar              10/26/2021                  1.0         102.4
# 4    Atharv Keskar              10/26/2021                  2.0         102.7
# ..             ...                     ...                  ...           ...
# 81    Skyla Dennis                 12/1/21                 38.0         101.8
# 82    Skyla Dennis                 12/1/21                 40.0         100.7
# 83    Skyla Dennis                 12/1/21                 41.0         102.1
# 84    Skyla Dennis                 12/1/21                 42.0         101.6
# 85    Skyla Dennis                 12/1/21                 46.0         101.9
#
#     EMPTY Comment  WET Collector WET Date (MM/DD/YYYY)  WET Bottle number  \
# 0             NaN    Kanako Kato            2021-10-21               31.0
# 1             NaN    Kanako Kato            2021-10-21               33.0
# 2             NaN    Kanako Kato            2021-10-21               47.0
# 3             NaN  Jordan Reding            2021-10-27                1.0
# 4             NaN  Jordan Reding            2021-10-27                2.0
# ..            ...            ...                   ...                ...
# 81            NaN   Skyla Dennis            2021-12-01               38.0
# 82            NaN   Skyla Dennis            2021-12-01               40.0
# 83            NaN   Skyla Dennis            2021-12-01               41.0
# 84            NaN   Skyla Dennis            2021-12-01               42.0
# 85            NaN   Skyla Dennis            2021-12-01               46.0
#
#     WET (gram)  Oven (C°)  ...  \
# 0        116.4        NaN  ...
# 1        117.1        NaN  ...
# 2        132.0        NaN  ...
# 3        133.8       55.0  ...
# 4        181.1       55.0  ...
# ..         ...        ...  ...
# 81       155.4        NaN  ...
# 82       129.7        NaN  ...
# 83       169.1        NaN  ...
# 84       134.0        NaN  ...
# 85       157.4        NaN  ...
#
#                                                Fruit   \
# 0   RIPE: Seeds, berries, or nuts appear to be mos...
# 1   NONE: Fruit is gone or is rare and isolated to...
# 2   RIPE: Seeds, berries, or nuts appear to be mos...
# 3      FALLEN: Most seeds, berries, or nuts are gone.
# 4      FALLEN: Most seeds, berries, or nuts are gone.
# ..                                                ...
# 81  NONE: Fruit is gone or is rare and isolated to...
# 82     FALLEN: Most seeds, berries, or nuts are gone.
# 83  NONE: Fruit is gone or is rare and isolated to...
# 84  NONE: Fruit is gone or is rare and isolated to...
# 85  NONE: Fruit is gone or is rare and isolated to...
#
#                              Phenology Comments  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3       Dispersing seeds still at good volumes
# 4   Seems to be on the latter of seasonal fruit
# ..                                          ...
# 81                                          NaN
# 82                                          NaN
# 83                                          NaN
# 84                                          NaN
# 85                                          NaN
#
#                                      General Comments  Weather Comments  \
# 0                                                 NaN               NaN
# 1                                                 NaN               NaN
# 2                                                 NaN               NaN
# 3   Old growth with some seeds and starting to die...         Sunny day
# 4          Some new and old growth with matured seeds             Sunny
# ..                                                ...               ...
# 81                                                NaN             sunny
# 82                                                NaN             shady
# 83                                                NaN             sunny
# 84                                                NaN             shady
# 85                                                NaN             shady
#
#     Old Growth                                         Location.1  \
# 0         31.0                                  Aquatics entrance
# 1         33.0                                  Aquatics entrance
# 2         47.0                                  Aquatics entrance
# 3          1.0                              Sweeney Hall entrance
# 4          2.0  San Salvador between 6th and 7th along South P...
# ..         ...                                                ...
# 81        38.0                                  Aquatics entrance
# 82        40.0                                       Art Building
# 83        41.0                                   Campus Village 2
# 84        42.0                                       Art Building
# 85        46.0                                   Campus Village 2
#
#    Diseased Dead  Flower Fruit  Temperature (°F)  Relative humidity
# 0            NaN           NaN               NaN                NaN
# 1           34.0           NaN               NaN                NaN
# 2            NaN           NaN               NaN                NaN
# 3            NaN           1.0               NaN                NaN
# 4            NaN           2.0               NaN                NaN
# ..           ...           ...               ...                ...
# 81           NaN           NaN               NaN                NaN
# 82           NaN           NaN               NaN                NaN
# 83           NaN           NaN               NaN                NaN
# 84           NaN           NaN               NaN                NaN
# 85           NaN           NaN               NaN                NaN
#
# [86 rows x 43 columns]

# %%
dead_disease_table=df1.merge(df2, how='inner', left_on=['WET Date (MM/DD/YYYY)', 'WET Bottle number'], right_on=['Timestamp', "Diseased Dead"])
dead_disease_table
# Out:
#   EMPTY Collector EMPTY Date (MM/DD/YYYY)  EMPTY Bottle number  EMPTY (gram)  \
# 0   Jordan Reding              10/14/2021                 34.0         101.3
# 1   Atharv Keskar              10/26/2021                  3.0         101.7
# 2    Skyla Dennis               11/3/2021                 45.0         101.1
# 3   Jordan Reding                 11/5/21                 32.0         101.6
# 4    Skyla Dennis                11/10/21                  7.0         101.1
# 5   Atharv Keskar                11/16/21                 27.0         101.0
# 6    Skyla Dennis                11/17/21                 12.0         101.6
# 7   Atharv Keskar                11/23/21                 25.0         101.5
# 8   Atharv Keskar                11/23/21                 30.0         101.5
#
#    EMPTY Comment  WET Collector WET Date (MM/DD/YYYY)  WET Bottle number  \
# 0            NaN    Kanako Kato            2021-10-21               34.0
# 1            NaN  Jordan Reding            2021-10-27                3.0
# 2            NaN   Skyla Dennis            2021-11-03               45.0
# 3            NaN  Jordan Reding            2021-11-05               32.0
# 4            NaN   Skyla Dennis            2021-11-10                7.0
# 5            NaN  Jordan Reding            2021-11-17               27.0
# 6            NaN   Skyla Dennis            2021-11-17               12.0
# 7            NaN  Jordan Reding            2021-11-24               25.0
# 8            NaN  Jordan Reding            2021-11-24               30.0
#
#    WET (gram)  Oven (C°)  ...  \
# 0       119.7        NaN  ...
# 1       157.9       55.0  ...
# 2       117.3       53.0  ...
# 3       154.2       55.0  ...
# 4       117.6        NaN  ...
# 5       152.0       69.0  ...
# 6       148.8       69.0  ...
# 7       149.5       75.0  ...
# 8       211.9       75.0  ...
#
#                                               Fruit   \
# 0  NONE: Fruit is gone or is rare and isolated to...
# 1  NONE: Fruit is gone or is rare and isolated to...
# 2  NONE: Fruit is gone or is rare and isolated to...
# 3     FALLEN: Most seeds, berries, or nuts are gone.
# 4  NONE: Fruit is gone or is rare and isolated to...
# 5     FALLEN: Most seeds, berries, or nuts are gone.
# 6  NONE: Fruit is gone or is rare and isolated to...
# 7     FALLEN: Most seeds, berries, or nuts are gone.
# 8  NONE: Fruit is gone or is rare and isolated to...
#
#                     Phenology Comments  \
# 0                                  NaN
# 1  Seems to bare no fruit at this time
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
# 8                                  NaN
#
#                                     General Comments  Weather Comments  \
# 0                                                NaN               NaN
# 1             Leaves are dying from seasonal change              Sunny
# 2  some of the leafs are turning yellow on the bo...        66 degrees
# 3                                                NaN             Sunny
# 4                                                NaN               NaN
# 5                                                NaN             Sunny
# 6                                                NaN        66 degrees
# 7                                                NaN             Sunny
# 8                                                NaN             Sunny
#
#    Old Growth                      Location.1 Diseased Dead  Flower Fruit  \
# 0        33.0               Aquatics entrance          34.0           NaN
# 1         3.0              National Bank Gate           3.0           NaN
# 2        27.0               Aquatics entrance          45.0           NaN
# 3        32.0              National Bank Gate          32.0           NaN
# 4        33.0               Aquatics entrance           7.0           NaN
# 5        27.0              National Bank Gate          27.0          27.0
# 6         7.0               Aquatics entrance          12.0           NaN
# 7        25.0                 Health Building          25.0           NaN
# 8        30.0  Recreation Center near islands          30.0           NaN
#
#    Temperature (°F)  Relative humidity
# 0               NaN                NaN
# 1               NaN                NaN
# 2               NaN                NaN
# 3               NaN                NaN
# 4               NaN                NaN
# 5               NaN                NaN
# 6               NaN                NaN
# 7               NaN                NaN
# 8               NaN                NaN
#
# [9 rows x 43 columns]

# %%
flower_table=df1.merge(df2, how='inner', left_on=['WET Date (MM/DD/YYYY)', 'WET Bottle number'], right_on=["Timestamp", "Flower Fruit"])
flower_table
# Out:
#    EMPTY Collector EMPTY Date (MM/DD/YYYY)  EMPTY Bottle number  EMPTY (gram)  \
# 0    Atharv Keskar              10/26/2021                  1.0         102.4
# 1    Atharv Keskar              10/26/2021                  2.0         102.7
# 2    Atharv Keskar              10/26/2021                  4.0         101.1
# 3    Atharv Keskar              10/26/2021                  5.0         101.8
# 4      Kanako Kato                 11/4/21                  4.0         101.1
# 5    Jordan Reding                 11/5/21                 30.0         101.8
# 6    Jordan Reding                 11/5/21                 31.0         102.2
# 7    Jordan Reding                 11/5/21                 33.0         101.3
# 8    Jordan Reding                 11/5/21                 34.0         101.4
# 9    Atharv Keskar                11/16/21                 26.0         102.0
# 10   Atharv Keskar                11/16/21                 27.0         101.0
# 11   Atharv Keskar                11/16/21                 28.0         101.9
# 12   Atharv Keskar                11/16/21                 31.0         102.0
# 13   Atharv Keskar                11/23/21                 26.0         101.8
# 14   Atharv Keskar                11/23/21                 28.0         101.9
#
#     EMPTY Comment  WET Collector WET Date (MM/DD/YYYY)  WET Bottle number  \
# 0             NaN  Jordan Reding            2021-10-27                1.0
# 1             NaN  Jordan Reding            2021-10-27                2.0
# 2             NaN  Jordan Reding            2021-10-27                4.0
# 3             NaN  Jordan Reding            2021-10-27                5.0
# 4             NaN    Kanako Kato            2021-11-04                4.0
# 5             NaN  Jordan Reding            2021-11-05               30.0
# 6             NaN  Jordan Reding            2021-11-05               31.0
# 7             NaN  Jordan Reding            2021-11-05               33.0
# 8             NaN  Jordan Reding            2021-11-05               34.0
# 9             NaN  Jordan Reding            2021-11-17               26.0
# 10            NaN  Jordan Reding            2021-11-17               27.0
# 11            NaN  Jordan Reding            2021-11-17               28.0
# 12            NaN  Jordan Reding            2021-11-17               31.0
# 13            NaN  Jordan Reding            2021-11-24               26.0
# 14            NaN  Jordan Reding            2021-11-24               28.0
#
#     WET (gram)  Oven (C°)  ...  \
# 0        133.8       55.0  ...
# 1        181.1       55.0  ...
# 2        169.5       55.0  ...
# 3        246.8       55.0  ...
# 4        158.2       85.0  ...
# 5        138.7       55.0  ...
# 6        193.6       55.0  ...
# 7        173.5       55.0  ...
# 8        244.9       55.0  ...
# 9        190.7       69.0  ...
# 10       152.0       69.0  ...
# 11       171.2       69.0  ...
# 12       284.1       69.0  ...
# 13       211.1       75.0  ...
# 14       195.3       75.0  ...
#
#                                                Fruit   \
# 0      FALLEN: Most seeds, berries, or nuts are gone.
# 1      FALLEN: Most seeds, berries, or nuts are gone.
# 2   RIPE: Seeds, berries, or nuts appear to be mos...
# 3   PRESENTING: Seeds, berries, or nuts are in vie...
# 4   RIPE: Seeds, berries, or nuts appear to be mos...
# 5   RIPE: Seeds, berries, or nuts appear to be mos...
# 6   RIPE: Seeds, berries, or nuts appear to be mos...
# 7   RIPE: Seeds, berries, or nuts appear to be mos...
# 8   RIPE: Seeds, berries, or nuts appear to be mos...
# 9      FALLEN: Most seeds, berries, or nuts are gone.
# 10     FALLEN: Most seeds, berries, or nuts are gone.
# 11  PRESENTING: Seeds, berries, or nuts are in vie...
# 12     FALLEN: Most seeds, berries, or nuts are gone.
# 13     FALLEN: Most seeds, berries, or nuts are gone.
# 14  RIPE: Seeds, berries, or nuts appear to be mos...
#
#                              Phenology Comments  \
# 0       Dispersing seeds still at good volumes
# 1   Seems to be on the latter of seasonal fruit
# 2                  Many needs seeds and few old
# 3                        Nearly developed seeds
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
#
#                                      General Comments  Weather Comments  \
# 0   Old growth with some seeds and starting to die...         Sunny day
# 1          Some new and old growth with matured seeds             Sunny
# 2   There is a lot of new growth and some old grow...             Sunny
# 3                                   More new than old             Sunny
# 4                                                 NaN               NaN
# 5                                                 NaN             Sunny
# 6                                                 NaN             Sunny
# 7                                                 NaN             Sunny
# 8                                                 NaN             Sunny
# 9                                                 NaN            Sunny
# 10                                                NaN             Sunny
# 11                                                NaN             Sunny
# 12                                                NaN             Sunny
# 13                                                NaN             Sunny
# 14                                                NaN             Sunny
#
#     Old Growth                                         Location.1  \
# 0          1.0                              Sweeney Hall entrance
# 1          2.0  San Salvador between 6th and 7th along South P...
# 2          4.0                                 National Bank Gate
# 3          5.0                                 National Bank Gate
# 4          6.0                                  Aquatics entrance
# 5         30.0                              Sweeney Hall entrance
# 6         31.0  San Salvador between 6th and 7th along South P...
# 7         33.0                                 National Bank Gate
# 8         34.0                                 National Bank Gate
# 9         26.0  San Salvador between 6th and 7th along South P...
# 10        27.0                                 National Bank Gate
# 11        28.0                                 National Bank Gate
# 12        31.0                                 National Bank Gate
# 13        26.0  San Salvador between 6th and 7th along South P...
# 14        28.0                                 National Bank Gate
#
#    Diseased Dead  Flower Fruit  Temperature (°F)  Relative humidity
# 0            NaN           1.0               NaN                NaN
# 1            NaN           2.0               NaN                NaN
# 2            NaN           4.0               NaN                NaN
# 3            NaN           5.0               NaN                NaN
# 4            NaN           4.0               NaN                NaN
# 5            NaN          30.0               NaN                NaN
# 6            NaN          31.0               NaN                NaN
# 7            NaN          33.0               NaN                NaN
# 8            NaN          34.0               NaN                NaN
# 9            NaN          26.0               NaN                NaN
# 10          27.0          27.0               NaN                NaN
# 11           NaN          28.0               NaN                NaN
# 12           NaN          31.0               NaN                NaN
# 13           NaN          26.0               NaN                NaN
# 14           NaN          28.0               NaN                NaN
#
# [15 rows x 43 columns]

# %% [markdown]
# creating table where theres is a additional column with state(old, new or dead/diseased) for future analysis. eg. mean difference in between growth state

# %%
#adding a state column and entering data 
old_table['state']='old'
new_table['state']='new'
dead_disease_table['state']='dead or diseased'

# %%
#taking only fuel moisuture and state column to have a cleaner df 
O_T=old_table[['fuel moisture percent', 'state']]
N_T=new_table[['fuel moisture percent', 'state']]
D_T=dead_disease_table[['fuel moisture percent', 'state']]

# %%
frames=[O_T, N_T, D_T]
OND=pd.concat(frames)

# %%
OND.to_csv('OND1.csv')#saving as csv

# %% [markdown]
# adding info of plants into merged table

# %%
from google.colab import files
files_uploaded = files.upload()
# Out:
#      <input type="file" id="files-2626b2b6-194d-4fe2-a7f7-58c0668d2ee7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2626b2b6-194d-4fe2-a7f7-58c0668d2ee7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HIZ plant info, site info, etc, - plant(5).csv to HIZ plant info, site info, etc, - plant(5).csv

# %%
df3= pd.read_csv(r'HIZ plant info, site info, etc, - plant(5).csv')
df3.columns = df3.iloc[0] 
df3 = df3[1:]

# %%
df3

# %% [markdown]
# old table with plant info

# %%
oldwithinfo=old_table.merge(df3, how='inner', left_on=['Common plant name'], right_on=["Common name (lower case unless proper noun)"])
oldwithinfo.to_csv('oldwithinfoUPDATED2.csv')#save it as csv
# Out:
#    EMPTY Collector EMPTY Date (MM/DD/YYYY)  EMPTY Bottle number  EMPTY (gram)  \
# 0    Jordan Reding              10/14/2021                 31.0         102.0
# 1      Kanako Kato                 11/4/21                  3.0         101.7
# 2    Atharv Keskar                11/23/21                 48.0         102.2
# 3    Jordan Reding              10/14/2021                 33.0         101.4
# 4    Atharv Keskar                11/23/21                 39.0         100.9
# ..             ...                     ...                  ...           ...
# 81      Sky Biblin                 11/5/21                 24.0         103.0
# 82      Sky Biblin                11/30/21                 24.0         102.8
# 83   Atharv Keskar                11/23/21                 43.0         101.6
# 84   Atharv Keskar                11/23/21                 44.0         101.8
# 85   Atharv Keskar                11/23/21                 47.0         100.9
#
#     EMPTY Comment WET Collector WET Date (MM/DD/YYYY)  WET Bottle number  \
# 0             NaN   Kanako Kato            2021-10-21               31.0
# 1             NaN   Kanako Kato            2021-11-04                3.0
# 2             NaN   Kanako Kato            2021-12-02               48.0
# 3             NaN   Kanako Kato            2021-10-21               33.0
# 4             NaN   Kanako Kato            2021-12-02               39.0
# ..            ...           ...                   ...                ...
# 81            NaN    Sky Biblin            2021-11-05               24.0
# 82            NaN    Sky Biblin            2021-11-30               24.0
# 83            NaN   Kanako Kato            2021-12-02               43.0
# 84            NaN   Kanako Kato            2021-12-02               44.0
# 85            NaN   Kanako Kato            2021-12-02               47.0
#
#     WET (gram)  Oven (C°)  ... Comment.spreading   Open Closed  \
# 0        116.4        NaN  ...               NaN  FALSE  FALSE
# 1        117.6       85.0  ...               NaN  FALSE  FALSE
# 2        114.1       80.0  ...               NaN  FALSE  FALSE
# 3        117.1        NaN  ...               NaN  FALSE  FALSE
# 4        131.4       80.0  ...               NaN  FALSE  FALSE
# ..         ...        ...  ...               ...    ...    ...
# 81       138.2        NaN  ...               NaN  FALSE  FALSE
# 82       138.5        NaN  ...               NaN  FALSE  FALSE
# 83       128.7       80.0  ...               NaN  FALSE  FALSE
# 84       150.0       80.0  ...               NaN  FALSE  FALSE
# 85       126.9       80.0  ...               NaN  FALSE  FALSE
#
#     Comment.branching  NaN                                                NaN  \
# 0                 NaN  NaN  King Filmer, Ann. Safe and Poisonous Garden Pl...
# 1                 NaN  NaN  King Filmer, Ann. Safe and Poisonous Garden Pl...
# 2                 NaN  NaN  King Filmer, Ann. Safe and Poisonous Garden Pl...
# 3                 NaN  NaN  King Filmer, Ann. Safe and Poisonous Garden Pl...
# 4                 NaN  NaN  King Filmer, Ann. Safe and Poisonous Garden Pl...
# ..                ...  ...                                                ...
# 81                NaN  NaN                                                NaN
# 82                NaN  NaN                                                NaN
# 83                NaN  NaN  King Filmer, Ann. Safe and Poisonous Garden Pl...
# 84                NaN  NaN  King Filmer, Ann. Safe and Poisonous Garden Pl...
# 85                NaN  NaN  King Filmer, Ann. Safe and Poisonous Garden Pl...
#
#                                                   NaN  \
# 0   California Integrated Pest Council (CAL IPC), ...
# 1   California Integrated Pest Council (CAL IPC), ...
# 2   California Integrated Pest Council (CAL IPC), ...
# 3   California Integrated Pest Council (CAL IPC), ...
# 4   California Integrated Pest Council (CAL IPC), ...
# ..                                                ...
# 81                                                NaN
# 82                                                NaN
# 83  California Integrated Pest Council (CAL IPC), ...
# 84  California Integrated Pest Council (CAL IPC), ...
# 85  California Integrated Pest Council (CAL IPC), ...
#
#                                                   NaN  NaN  NaN
# 0                                                 NaN  NaN  NaN
# 1                                                 NaN  NaN  NaN
# 2                                                 NaN  NaN  NaN
# 3                                                 NaN  NaN  NaN
# 4                                                 NaN  NaN  NaN
# ..                                                ...  ...  ...
# 81                                                NaN  NaN  NaN
# 82                                                NaN  NaN  NaN
# 83                                                NaN  NaN  NaN
# 84                                                NaN  NaN  NaN
# 85  , . Live Oak. National Park Website, , , https...  NaN  NaN
#
# [86 rows x 91 columns]

# %%
newinfo_table=avg_new.merge(df3, how='inner', left_on=['Common plant name'], right_on=["Common name (lower case unless proper noun)"])
newinfo_table
# Out:
#        Common plant name  fuel moisture percent Family (ends in -aceae)  \
# 0   Australian pine tree              95.306667           Casuarinaceae
# 1     Canary Island pine             121.545000                Pinaceae
# 2           Mexican sage             436.540000               Lamiaceae
# 3                boxwood             228.336667                Buxaceae
# 4          coast redwood             154.662500            Cupressaceae
# 5           coffee berry             274.360000              Rhamnaceae
# 6                jasmine             223.930000  Oleaceae- Olive Family
# 7                lantana             250.550000             Verbenaceae
# 8             olive tree             109.460000                Oleaceae
# 9              wild rose             216.130000                Rosaceae
# 10                yarrow             437.250000              Asteraceae
#
#                  Latin name Common name (lower case unless proper noun)  \
# 0   Casuarina equisetifolia                        Australian pine tree
# 1         Pinus canariensis                          Canary Island pine
# 2                Salvia sp.                                Mexican sage
# 3                 Buxus sp.                                     boxwood
# 4      Sequoia sempervirens                               coast redwood
# 5               Rhamnus sp.                                coffee berry
# 6               Jasmine sp.                                     jasmine
# 7                   Vervain                                     lantana
# 8             Olea europaea                                  olive tree
# 9          Rosa californica                                   wild rose
# 10      Achillea millefolia                                      yarrow
#
#    Native Non-native Unknown  Grass   Herb  ... Comment.spreading   Open  \
# 0   FALSE       TRUE   FALSE  FALSE  FALSE  ...               NaN  FALSE
# 1   FALSE       TRUE   FALSE  FALSE  FALSE  ...               NaN  FALSE
# 2   FALSE      FALSE    TRUE  FALSE  FALSE  ...               NaN  FALSE
# 3   FALSE       TRUE   FALSE  FALSE  FALSE  ...               NaN  FALSE
# 4    TRUE      FALSE   FALSE  FALSE  FALSE  ...               NaN  FALSE
# 5    TRUE      FALSE   FALSE  FALSE  FALSE  ...               NaN  FALSE
# 6   FALSE       TRUE   FALSE  FALSE  FALSE  ...               NaN  FALSE
# 7   FALSE       TRUE   FALSE  FALSE   TRUE  ...               NaN  FALSE
# 8   FALSE       TRUE   FALSE  FALSE  FALSE  ...               NaN  FALSE
# 9    TRUE      FALSE   FALSE  FALSE  FALSE  ...               NaN  FALSE
# 10   TRUE      FALSE   FALSE  FALSE   TRUE  ...               NaN  FALSE
#
#    Closed Comment.branching NaN  \
# 0   FALSE               NaN NaN
# 1   FALSE               NaN NaN
# 2   FALSE               NaN NaN
# 3   FALSE               NaN NaN
# 4   FALSE               NaN NaN
# 5   FALSE               NaN NaN
# 6   FALSE               NaN NaN
# 7   FALSE               NaN NaN
# 8   FALSE               NaN NaN
# 9   FALSE               NaN NaN
# 10  FALSE               NaN NaN
#
#                                                   NaN  \
# 0   King Filmer, Ann. Safe and Poisonous Garden Pl...
# 1                                                 NaN
# 2   King Filmer, Ann. Safe and Poisonous Garden Pl...
# 3   Record, Samuel J. Boxwoods. Boxwoods, Yale Sch...
# 4   King Filmer, Ann. Safe and Poisonous Garden Pl...
# 5   Saupe, Stephen G. Plant Taxonomy. Plant Taxono...
# 6   , . Jasmine. , American Society for the Preven...
# 7   Saupe, Stephen G. Plant Taxonomy. Plant Taxono...
# 8   Zhou,  Lijun. et al. Volatile compound analysi...
# 9   King Filmer, Ann. Safe and Poisonous Garden Pl...
# 10  Saupe, Stephen G. Plant Taxonomy. Plant Taxono...
#
#                                                   NaN  \
# 0   , . Australian Pine Tree (Casuarina equisetifo...
# 1   King Filmer, Ann. Safe and Poisonous Garden Pl...
# 2                                                 NaN
# 3   King Filmer, Ann. Safe and Poisonous Garden Pl...
# 4                                                 NaN
# 5   King Filmer, Ann. Safe and Poisonous Garden Pl...
# 6   , . Chemical Composition, Olfactory Evaluation...
# 7   King Filmer, Ann. Safe and Poisonous Garden Pl...
# 8                                                 NaN
# 9   California Integrated Pest Council (CAL IPC), ...
# 10  King Filmer, Ann. Safe and Poisonous Garden Pl...
#
#                                                   NaN  \
# 0                                                 NaN
# 1   California Integrated Pest Council (CAL IPC), ...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   Ortiz, Americo. et al. Volatile Composition of...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
#
#                                                   NaN  NaN
# 0                                                 NaN  NaN
# 1                                                 NaN  NaN
# 2   Conde-Hernández, L. A. et al. Mexican Sage (Sa...  NaN
# 3                                                 NaN  NaN
# 4                                                 NaN  NaN
# 5                                                 NaN  NaN
# 6                                                 NaN  NaN
# 7                                                 NaN  NaN
# 8                                                 NaN  NaN
# 9                                                 NaN  NaN
# 10                                                NaN  NaN
#
# [11 rows x 49 columns]

# %%
ddinfo_table=avg_disease.merge(df3, how='inner', left_on=['Common plant name'], right_on=["Common name (lower case unless proper noun)"])
ddinfo_table
# Out:
#   Common plant name  fuel moisture percent Family (ends in -aceae)  \
# 0        deer grass              76.920000                 Poaceae
# 1            gingko             103.310000             Ginkgoaceae
# 2        olive tree             101.680000                Oleaceae
# 3         sweet gum             101.463333            Altingiaceae
# 4            yarrow              41.070000              Asteraceae
#
#                 Latin name Common name (lower case unless proper noun) Native  \
# 0      Muhlenbergia rigens                                  deer grass   TRUE
# 1            Gingko biloba                                      gingko  FALSE
# 2            Olea europaea                                  olive tree  FALSE
# 3  Liquidambar styraciflua                                   sweet gum  FALSE
# 4      Achillea millefolia                                      yarrow   TRUE
#
#   Non-native Unknown  Grass   Herb  ... Comment.spreading   Open Closed  \
# 0      FALSE   FALSE   TRUE  FALSE  ...               NaN  FALSE  FALSE
# 1       TRUE   FALSE  FALSE  FALSE  ...               NaN  FALSE  FALSE
# 2       TRUE   FALSE  FALSE  FALSE  ...               NaN  FALSE  FALSE
# 3       TRUE   FALSE  FALSE  FALSE  ...               NaN  FALSE  FALSE
# 4      FALSE   FALSE  FALSE   TRUE  ...               NaN  FALSE  FALSE
#
#   Comment.branching NaN                                                NaN  \
# 0               NaN NaN  King Filmer, Ann. Safe and Poisonous Garden Pl...
# 1               NaN NaN  Li , Dewen. el al. Impact of elevated CO2 and ...
# 2               NaN NaN  Zhou,  Lijun. et al. Volatile compound analysi...
# 3               NaN NaN  Kormanik, Paul P. Sweetgum. Southern Research ...
# 4               NaN NaN  Saupe, Stephen G. Plant Taxonomy. Plant Taxono...
#
#                                                  NaN  \
# 0  California Integrated Pest Council (CAL IPC), ...
# 1                                                NaN
# 2                                                NaN
# 3  King Filmer, Ann. Safe and Poisonous Garden Pl...
# 4  King Filmer, Ann. Safe and Poisonous Garden Pl...
#
#                                                  NaN  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  California Integrated Pest Council (CAL IPC), ...
# 4                                                NaN
#
#                                                  NaN  NaN
# 0                                                NaN  NaN
# 1                                                NaN  NaN
# 2                                                NaN  NaN
# 3  Fang, Chengwei. et al. Isoprene emission, phot...  NaN
# 4                                                NaN  NaN
#
# [5 rows x 49 columns]

# %% [markdown]
# you can concat all oldwithinfo, newinfo, ddinfo if you want for table which consist of all fuel mositure info with plant info

# %% [markdown]
# Adding irrigation info into old fuel moisture table

# %%
from google.colab import files
files_uploaded = files.upload()
# Out:
#      <input type="file" id="files-9344dcc6-22a2-476c-a901-699cecae3a13" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9344dcc6-22a2-476c-a901-699cecae3a13">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HIZ plant info, site info, etc, - site, data collector, semester.csv to HIZ plant info, site info, etc, - site, data collector, semester.csv

# %%
DF2= pd.read_csv(r'HIZ plant info, site info, etc, - site, data collector, semester.csv')

# %%
#DF2.columns = DF2.columns.str.replace(' ','_')#deleting space
DF2=DF2.drop(['Semester','Collection time','Slope percent','Aspect (0-360 degrees)','Elevation (m)', 'General site description','Shade at 12 noon on summer solstice','Shade at 12 noon on fall equinox','Latitude','Longitude','Associated weather station','Comments'], axis=1)
DF2=DF2.drop_duplicates()

# %% [markdown]
# merge irrigation info to old with info

# %%
DF3=oldwithinfo.merge(DF2, how='left', left_on=['Common plant name', 'WET Collector'], right_on=["Common name", 'Data collector'])

# %%
DF3.to_csv('oldwithirrigation.csv')#save it as csv

# %% [markdown]
# NOTE:
# new  growth, flower, dead and disease did not have many data points

# %% [markdown]
# # **extra**
# quick data analysis: finding avg fuel mositure bycommon name on different growth state

# %%
avg_new=new_table.groupby('Common plant name', as_index=False)['fuel moisture percent'].mean()
avg_new
# Out:
#        Common plant name  fuel moisture percent
# 0   Australian pine tree              95.306667
# 1     Canary Island pine             121.545000
# 2           Mexican sage             436.540000
# 3                boxwood             228.336667
# 4          coast redwood             154.662500
# 5           coffee berry             274.360000
# 6                jasmine             223.930000
# 7                lantana             250.550000
# 8             olive tree             109.460000
# 9              wild rose             216.130000
# 10                yarrow             437.250000

# %%
ax= avg_new.plot.bar("Common plant name", y="fuel moisture percent", rot=90)

# %% [markdown]
# avg fuel moisture old growth

# %%
avg_old=old_table.groupby('Common plant name', as_index=False)['fuel moisture percent'].mean()
avg_old
# Out:
#         Common plant name  fuel moisture percent
# 0            African lily             690.160000
# 1            Algerian ivy             188.300000
# 2             Asian maple              97.210000
# 3    Australian pine tree              97.222500
# 4   California bay laurel             134.250000
# 5      Canary Island pine             121.545000
# 6            Guelder-rose             144.586667
# 7            Mexican sage             437.760000
# 8                 boxwood             163.835000
# 9          coast live oak              76.870000
# 10          coast redwood             154.662500
# 11           coffee berry             214.697500
# 12           crepe myrtle             143.383333
# 13             deer grass             276.540000
# 14       giant chain fern             212.546667
# 15                 gingko             148.975000
# 16     horseshoe geranium             419.346667
# 17                jasmine             206.967500
# 18                lantana             250.960000
# 19         magenta cherry             357.486667
# 20             olive tree             109.907500
# 21         swamp mahogany             110.906667
# 22              sweet gum             100.582500
# 23              wild rose             138.975000
# 24                 yarrow             524.682500

# %%
ax= avg_old.plot.bar("Common plant name", y="fuel moisture percent", rot=90)

# %%
avg_flower=flower_table.groupby('Common plant name', as_index=False)['fuel moisture percent'].mean()
avg_flower
# Out:
#       Common plant name  fuel moisture percent
# 0           Asian maple              97.105000
# 1  Australian pine tree              97.222500
# 2    Canary Island pine             120.916667
# 3         coast redwood             154.662500
# 4          crepe myrtle             119.620000
# 5             sweet gum              83.450000

# %%
ax= avg_flower.plot.bar("Common plant name", y="fuel moisture percent", rot=90)

# %%
avg_disease=dead_disease_table.groupby('Common plant name', as_index=False)['fuel moisture percent'].mean()
avg_disease
# Out:
#   Common plant name  fuel moisture percent
# 0        deer grass              76.920000
# 1            gingko             103.310000
# 2        olive tree             101.680000
# 3         sweet gum             101.463333
# 4            yarrow              41.070000

# %%
ax= avg_disease.plot.bar("Common plant name", y="fuel moisture percent", rot=90)
